# %%
from pyspark import SparkContext, SparkConf #spark
from pyspark.sql import SQLContext # for data frame
import re #for escape string

# %%
import graphlab as gl #for graph, sframe

# %%
conf = SparkConf().setAppName("error_machine_part_3")
sc = SparkContext(conf=conf)

# %%
def Count_Lines(df_path):
    '''
    counting lines of the file
    '''
    rdd_hdfs = sc.textFile(df_path)
    count_lines = rdd_hdfs.count()
    return count_lines

# %%
def Word_Count_Each_Text(df_path):
    '''
    [(u'', 483648),
     (u'virtual', 11546),
     (u'jerry', 11365),
     (u'Jan', 11364),
     (u'machine', 11364),
     (u'NetworkManager', 4390),
     (u'info', 4327)]
    '''
    rdd_hdfs = sc.textFile(df_path)
    count_lines = rdd_hdfs.count()
    # spliting by special characters and number
    rdd_split_map = rdd_hdfs.flatMap(lambda x: re.split(r'[`\- =~!@#$%^&*()_+\[\]{};\'\\:"|<,./<>?0-9]', x),1)
    #ready to count
    rdd_count_map = rdd_split_map.map(lambda x: (x, 1))
    #mapping each key and counting it
    res_reduce = rdd_count_map.reduceByKey(lambda a, b: a+b )
    # desc sorting by counting number
    res_reduce = res_reduce.sortBy(lambda c: c[1], False)
    return res_reduce

# %%
def Pick_Top_Text(rdd_wc_reduce, count_lines):
    '''
    picking string which always show and counting bigger than file lines  (deviation value 2)
    '''
    pick_top_string_map = rdd_wc_reduce.filter(lambda x: x[1] >= count_lines-2)
    pick_top_string_map.collect()
    return pick_top_string_map.collect()

# %%
def Map_Filter_Top_Texts(line, list_tops):
    '''
    filter all the top text 
    if len(text) > len(file lines):
    then delete text
    '''
    res_str = ""
    for text in line:
        flag = 0
        if str(text) == "":
            continue;
        for top in list_tops:
            #res_str +='----' +top[0]
            if top[0] == str(text):

                flag = 1
                break;
        if(flag == 1):
            continue;
        else:
            res_str +="," + str(text)
    return res_str[1:]

# %%
def Gen_Relative_Table(col_rdd):
    '''
    0 1 2
    A B C
    
    relative[A] = [B]
    relative[B] = [A,C]
    relative[C] = [B]
    '''
    dist_text = {}
    for str_line in col_rdd:
        line = str_line.split(',')
        for i in range(0,len(line)):
            now = line[i]
            if now not in dist_text:
                dist_text[now] = []
            if i == 0 and i != len(line) -1:
                dist_text[now].append( line[i+1] )
            elif i == len(line) -1 :
                dist_text[now].append( line[i-1] )
            else:
                dist_text[now].append( line[i+1] )
                dist_text[now].append( line[i-1] )

    for text in dist_text:
        set_dist = set(dist_text[text])
        dist_text[text] = list(set_dist)
    return dist_text

# %%
def Count_Each_Line_Score_zero(col_rdd, relative_table):
    pass
    '''
    for each text
        query relative table if not found this keyword ->score = 0
        if found this keyword and find it's relative world -> score += 1
    line score = text score / (line length - 1)

    list_res = []
    list_zero_line_number = []
    list_zero_line_content = []
    number = 0
    for str_line in col_rdd:
        number += 1
        line = str_line.split(',')
        score_line = 0.0
        len_line = len(line)
        if len_line > 1:
            for i in range(0,len_line):
                now = line[i]
                if now not in relative_table:
                    score_line += 0
                elif i != (len_line -1):
                    next = line[i+1]
                    for relative in relative_table[now]:
                        if next == relative:
                            score_line += 1
            score_line = score_line/(len_line-1)
        list_res.append(score_line)
        if score_line == 0.0:
            list_zero_line_number.append(number)
            list_zero_line_content.append(str_line)
    return (list_res,list_zero_line_number,list_zero_line_content)
    '''

# %%
def Count_Each_Line_Score(col_rdd, relative_table):
    '''
    for each text
        len(text) in a line < 1 => score = 0
        query relative table if not found this keyword =>score = 0
        if finding this keyword and finding it's relative world => score += 1
    line score = text score / (line length - 1)
    
    relative[A] = [B]
    relative[B] = [A,C]
    relative[C] = [B]
    
    ex: line 1 = ABDCA 
        => 1+1+0+0
    '''
    list_score = []
    list_line_number = []
    list_error_content = []
    number = 0
    for str_line in col_rdd:
        number += 1
        line = str_line.split(',')
        score_line = 0.0
        len_line = len(line)
        error_text = ""
        if len_line > 1:
            for i in range(0,len_line):
                tag_find = 0
                now = line[i]
                if now not in relative_table:
                    score_line += 0
                    error_text += ","
                    error_text += now
                elif i != (len_line -1):
                    next = line[i+1]
                    for relative in relative_table[now]:
                        if next == relative:
                            score_line += 1
                            tag_find = 1
                            break;
                    if tag_find == 0:
                        error_text += ","
                        error_text += now
            score_line = score_line/(len_line-1)
        else:
            error_text += ","
            error_text += now
            
        list_score.append(score_line)
        list_line_number.append(number)
        list_error_content.append(error_text[1:])       
    return (list_line_number, list_score, list_error_content)

# %%
def Delete_Top_Text_for_Each_Line(df_path, top_collect):
    '''
    filter all top text for each line
    '''
    rdd_hdfs = sc.textFile(df_path)
    # spliting by special characters
    rdd_sp_map = rdd_hdfs.map(lambda x: re.split(r'[`\- =~!@#$%^&*()_+\[\]{};\'\\:"|<,./<>?0-9]', x),1)
    #filter all top text for each line
    rdd_fil_map = rdd_sp_map.map(lambda x:Map_Filter_Top_Texts(x, top_collect) )
    return rdd_fil_map

# %%
def Gen_Relative_Table_by_Filter_Map(rdd_fil_map):
    '''
    before this function, all text line must to filter by texts of top rank
    then generate a relation table
    '''
    col_rdd_fil = rdd_fil_map.collect()
    dist_relative_table = Gen_Relative_Table(col_rdd_fil)
    return dist_relative_table

# %%
def Query_Score_Range_Lines(score_lines, list_error_content, int_start_score, int_end_score):
    '''
    according the range of score to generate list
    '''
    len_lines = len(score_lines)
    list_content = []
    list_score = []
    list_number = []
    for i in range(0,len_lines):
        score = score_lines[i]
        if score >= int_start_score and score <= int_end_score:
            list_content.append(list_error_content [i])
            list_score.append(score)
            list_number.append(i+1)
    return (list_number,list_score,list_content)

# %%
def Main_Normal_Case(input_path):
    count_lines = Count_Lines(input_path)
    red_wordcount = Word_Count_Each_Text(input_path)
    col_red_top = Pick_Top_Text(red_wordcount, count_lines)
    rdd_map_filiter_top = Delete_Top_Text_for_Each_Line(input_path, col_red_top)
    dist_table = Gen_Relative_Table_by_Filter_Map(rdd_map_filiter_top)
    return dist_table

# %%
def Main_Compare_Case(input_path, normal_path):
    count_lines = Count_Lines(input_path)
    red_wordcount = Word_Count_Each_Text(input_path)
    col_red_top = Pick_Top_Text(red_wordcount, count_lines)
    rdd_map_filiter_top = Delete_Top_Text_for_Each_Line(input_path, col_red_top)
    dist_main_relative_table = Main_Normal_Case(normal_path)
    number, list_score,list_error_content = Count_Each_Line_Score(rdd_map_filiter_top.collect(), dist_main_relative_table)
    return number, list_score, list_error_content

# %%
inputPath_normal = '/user/spark/input/log_normal'

# %%
inputPath_compare = '/user/spark/input/log_error'

# %%
list_number, list_score, list_error_content = Main_Compare_Case(inputPath_compare, inputPath_normal)

# %%
len_list = len(list_score)
for i in range(0,len_list):
    print list_number[i],list_score[i],list_error_content[i]
# Out:
# 1 1.0
# 2 1.0
# 3 1.0
# 4 1.0
# 5 1.0
# 6 1.0
# 7 1.0
# 8 1.0
# 9 1.0
# 10 1.0
# 11 1.0
# 12 1.0
# 13 1.0
# 14 1.0
# 15 1.0
# 16 1.0
# 17 1.0
# 18 1.0
# 19 1.0
# 20 1.0
# 21 1.0
# 22 1.0
# 23 1.0
# 24 1.0
# 25 0.3 CMD,command,v,debian,sa,null,debian,sa
# 26 1.0
# 27 1.0
# 28 1.0
# 29 1.0
# 30 1.0
# 31 1.0
# 32 1.0
# 33 1.0
# 34 1.0
# 35 1.0
# 36 1.0
# 37 1.0
# 38 1.0
# 39 1.0
# 40 1.0
# 41 1.0
# 42 1.0
# 43 1.0
# 44 1.0
# 45 0.3 CMD,command,v,debian,sa,null,debian,sa
# 46 1.0
# 47 1.0
# 48 1.0
# 49 1.0
# 50 1.0
# 51 0.3 CMD,command,v,debian,sa,null,debian,sa
# 52 1.0
# 53 1.0
# 54 1.0
# 55 1.0
# 56 1.0
# 57 1.0
# 58 1.0
# 59 1.0
# 60 1.0
# 61 1.0
# 62 1.0
# 63 1.0
# 64 1.0
# 65 1.0
# 66 1.0
# 67 1.0
# 68 1.0
# 69 1.0
# 70 1.0
# 71 1.0
# 72 1.0
# 73 1.0
# 74 0.3 CMD,command,v,debian,sa,null,debian,sa
# 75 1.0
# 76 1.0
# 77 1.0
# 78 1.0
# 79 1.0
# 80 1.0
# 81 1.0
# 82 1.0
# 83 1.0
# 84 1.0
# 85 1.0
# 86 1.0
# 87 1.0
# 88 1.0
# 89 1.0
# 90 1.0
# 91 1.0
# 92 1.0
# 93 1.0
# 94 1.0
# 95 0.3 CMD,command,v,debian,sa,null,debian,sa
# 96 1.0
# 97 1.0
# 98 1.0
# 99 1.0
# 100 1.0
# 101 1.0
# 102 1.0
# 103 1.0
# 104 1.0
# 105 1.0
# 106 1.0
# 107 1.0
# 108 1.0
# 109 1.0
# 110 1.0
# 111 1.0
# 112 1.0
# 113 1.0
# 114 1.0
# 115 1.0
# 116 1.0
# 117 1.0
# 118 1.0
# 119 0.3 CMD,command,v,debian,sa,null,debian,sa
# 120 1.0
# 121 1.0
# 122 1.0
# 123 1.0
# 124 1.0
# 125 0.3 CMD,command,v,debian,sa,null,debian,sa
# 126 1.0
# 127 1.0
# 128 1.0
# 129 1.0
# 130 1.0
# 131 1.0
# 132 1.0
# 133 1.0
# 134 1.0
# 135 1.0
# 136 1.0
# 137 1.0
# 138 1.0
# 139 1.0
# 140 1.0
# 141 1.0
# 142 1.0
# 143 1.0
# 144 1.0
# 145 1.0
# 146 1.0
# 147 1.0
# 148 0.3 CMD,command,v,debian,sa,null,debian,sa
# 149 1.0
# 150 1.0
# 151 1.0
# 152 1.0
# 153 1.0
# 154 1.0
# 155 1.0
# 156 1.0
# 157 1.0
# 158 1.0
# 159 1.0
# 160 1.0
# 161 1.0
# 162 1.0
# 163 1.0
# 164 1.0
# 165 1.0
# 166 1.0
# 167 1.0
# 168 0.3 CMD,command,v,debian,sa,null,debian,sa
# 169 1.0
# 170 1.0
# 171 1.0
# 172 1.0
# 347 1.0
# 348 1.0
# 349 1.0
# 350 1.0
# 351 1.0
# 352 0.3 CMD,command,v,debian,sa,null,debian,sa
# 353 1.0
# 354 1.0
# 355 1.0
# 356 1.0
# 357 1.0
# 358 1.0
# 359 1.0
# 360 1.0
# 361 1.0
# 362 1.0
# 363 1.0
# 364 1.0
# 365 1.0
# 366 1.0
# 367 1.0
# 368 1.0
# 369 1.0
# 370 1.0
# 371 1.0
# 372 1.0
# 373 1.0
# 374 1.0
# 375 1.0
# 376 0.3 CMD,command,v,debian,sa,null,debian,sa
# 377 1.0
# 378 1.0
# 379 1.0
# 380 1.0
# 381 1.0
# 382 1.0
# 383 1.0
# 384 1.0
# 385 1.0
# 386 1.0
# 387 1.0
# 388 1.0
# 389 1.0
# 390 1.0
# 391 1.0
# 392 1.0
# 393 1.0
# 394 1.0
# 395 1.0
# 396 1.0
# 397 1.0
# 398 1.0
# 399 1.0
# 400 1.0
# 401 1.0
# 402 1.0
# 403 1.0
# 404 1.0
# 405 1.0
# 406 0.3 CMD,command,v,debian,sa,null,debian,sa
# 407 1.0
# 408 1.0
# 409 1.0
# 410 1.0
# 411 1.0
# 412 1.0
# 413 1.0
# 414 1.0
# 415 1.0
# 416 1.0
# 417 1.0
# 418 1.0
# 419 1.0
# 420 1.0
# 421 1.0
# 422 1.0
# 423 1.0
# 424 1.0
# 425 1.0
# 426 0.3 CMD,command,v,debian,sa,null,debian,sa
# 427 1.0
# 428 1.0
# 429 1.0
# 430 1.0
# 431 0.3 CMD,command,v,debian,sa,null,debian,sa
# 432 1.0
# 433 1.0
# 434 1.0
# 435 1.0
# 436 1.0
# 437 1.0
# 438 1.0
# 439 1.0
# 440 1.0
# 441 1.0
# 442 1.0
# 443 1.0
# 444 1.0
# 445 1.0
# 446 1.0
# 447 1.0
# 448 1.0
# 449 1.0
# 450 1.0
# 451 1.0
# 452 1.0
# 453 0.9 s,nmbd
# 454 1.0
# 455 0.75 in,btrfs
# 456 0.0 kernel,btrfs,xor
# 457 0.0 kernel,xor
# 458 1.0
# 459 0.0 kernel,raid,pq
# 460 0.0 kernel,raid,pq
# 461 0.0 kernel,btrfs,xor,raid,pq,ufs,qnx
# 462 0.0 kernel,ufs,ufs,qnx
# 463 0.0 kernel,qnx,hfsplus
# 464 0.0 kernel,hfsplus,hfs
# 465 0.0 kernel,hfs,minix
# 466 0.0 kernel,minix
# 467 0.0 kernel,ntfs,msdos
# 468 0.0 kernel,ntfs,hfsplus,hfs
# 469 0.0 kernel,jfs
# 470 0.0 kernel,minix
# 471 0.0 kernel,msdos
# 472 0.0 kernel,ntfs
# 473 0.0 kernel,jfs,xfs
# 474 0.0 kernel,msdos,jfs,xfs
# 475 0.0 kernel,xfs,libcrc
# 476 0.2 kernel,libcrc,c,libcrc
# 477 0.5 veth
# 478 0.75 kernel
# 479 0.833333333333 kernel
# 480 0.75 kernel
# 481 0.75 kernel
# 482 0.75 kernel
# 483 1.0
# 484 1.0
# 485 0.8 kernel
# 486 0.75 kernel
# 487 0.0 kernel,vhost,vhost
# 488 0.0 kernel,macvtap
# 489 0.0 kernel
# 490 0.0 kernel
# 491 0.0 kernel
# 492 0.0 kernel
# 493 0.5 kernel
# 494 0.5 kernel
# 495 0.75 kernel
# 496 0.833333333333 kernel
# 497 0.5 kernel
# 498 0.5 kernel
# 499 0.928571428571 kernel
# 500 0.941176470588 kernel
# 501 0.857142857143 kernel
# 502 0.833333333333 kernel
# 503 0.875 kernel
# 504 0.857142857143 kernel
# 505 0.5 kernel
# 506 0.666666666667 kernel
# 507 0.666666666667 kernel
# 508 0.833333333333 kernel
# 509 0.888888888889 kernel
# 510 0.833333333333 kernel
# 511 0.9 transport
# 512 0.933333333333 kernel,transport
# 513 0.857142857143 kernel,vsock
# 514 0.75 kernel,vsock
# 515 0.75 kernel
# 516 0.8 kernel
# 517 0.714285714286 kernel,codec
# 518 0.5 kernel,gameport
# 519 0.75 kernel
# 520 0.75 kernel
# 521 0.8 kernel
# 522 0.833333333333 kernel
# 523 0.875 kernel
# 524 0.833333333333 kernel
# 525 0.75 kernel
# 526 0.0 kernel,coretemp
# 527 0.666666666667 kernel
# 528 0.75 kernel
# 529 0.833333333333 kernel
# 530 0.8 kernel
# 531 0.75 kernel
# 532 0.75 kernel
# 533 0.666666666667 kernel
# 534 0.0 kernel,snd
# 535 0.0 kernel,kvm
# 536 0.0 kernel
# 537 0.0 kernel
# 538 0.666666666667 kernel
# 539 0.666666666667 kernel
# 540 0.8 kernel
# 541 0.0 kernel,irqbypass
# 542 0.571428571429 kernel,leds,balloon
# 543 0.75 kernel
# 544 0.666666666667 kernel
# 545 0.0 kernel,nfit
# 546 0.4 kernel,shpchp,shpchp
# 547 0.857142857143 kernel
# 548 0.714285714286 kernel,piix
# 549 0.5 kernel,fintek
# 550 0.5 kernel
# 551 0.75 kernel
# 552 0.8 kernel
# 553 0.0 kernel
# 554 0.5 kernel
# 555 0.333333333333 kernel,lp
# 556 0.5 kernel
# 557 0.8 kernel
# 558 0.8 kernel
# 559 0.0 kernel
# 560 0.0 kernel
# 561 0.5 kernel
# 562 0.5 kernel
# 563 0.5 kernel
# 564 0.0 kernel
# 565 0.0 kernel
# 566 0.0 kernel
# 567 0.0 kernel
# 568 0.0 kernel
# 569 0.0 kernel
# 570 0.0 kernel
# 571 0.0 kernel
# 572 0.5 kernel
# 573 0.0 kernel
# 574 0.0 kernel
# 575 0.666666666667 kernel
# 576 0.666666666667 kernel
# 577 0.666666666667 kernel
# 578 0.0 kernel
# 579 0.0 kernel
# 580 0.0 kernel
# 581 0.0 kernel
# 582 0.0 kernel
# 583 0.5 kernel
# 584 0.333333333333 kernel,sysfillrect
# 585 0.5 kernel
# 586 0.833333333333 kernel
# 587 0.714285714286 kernel,fops
# 588 0.5 kernel
# 589 0.5 kernel
# 590 1.0
# 591 0.0 kernel
# 592 0.0 kernel
# 593 0.0 kernel
# 594 0.0 kernel
# 595 0.666666666667 kernel
# 596 0.666666666667 kernel
# 597 0.888888888889 kernel
# 598 0.8 kernel
# 599 0.0 kernel
# 600 0.0 kernel
# 601 0.0 fjes
# 602 0.0 fjes
# 603 0.777777777778 Comm,nmbd
# 604 0.9 u
# 605 1.0
# 606 1.0
# 607 1.0
# 608 0.875 d
# 609 1.0
# 610 1.0
# 611 1.0
# 612 0.142857142857 Workqueue,events,freezable,power,disk,events
# 613 0.888888888889 d
# 614 0.0 ffff
# 615 0.6 d,ffff,fb,ffff
# 616 0.75 RIP
# 617 0.75 a
# 618 0.625 e,do,softirq
# 619 0.6 RBX,d
# 620 0.666666666667 RIP
# 621 0.875 RSI
# 622 0.375 f,raw,spin,unlock,irqrestore
# 623 0.833333333333 a
# 624 0.666666666667 ffff,de
# 625 0.75 ffff,de
# 626 0.666666666667 ffff
# 627 0.888888888889 fd
# 628 0.25 RAX,RBX,ffff
# 629 1.0
# 630 0.875 e
# 631 0.666666666667 RDX
# 632 0.6 R,ffffffff
# 633 0.8 f
# 634 0.666666666667 R,ffffea,a
# 635 0.166666666667 RAX,ffff,fbc,RBX,dc
# 636 0.666666666667 ffff,ab
# 637 0.8 b
# 638 0.75 FS,a
# 639 0.875 f
# 640 1.0
# 641 0.666666666667 R,e
# 642 0.714285714286 CR,c
# 643 0.857142857143 f
# 644 1.0
# 645 1.0
# 646 0.666666666667 f,ee
# 647 1.0
# 648 1.0
# 649 0.0 kernel,ab
# 650 0.75 ffff,fbc
# 651 0.25 ffffffffc,bd,c
# 652 1.0
# 653 0.0 kernel
# 654 1.0
# 655 1.0
# 656 1.0
# 657 0.0 b
# 658 0.0 b
# 659 0.5 a,ab
# 660 0.0 d
# 661 0.0 d
# 662 0.0 kernel
# 663 1.0
# 664 1.0
# 665 0.5 ffff
# 666 0.0 ab
# 667 1.0
# 668 1.0
# 669 1.0
# 670 1.0
# 671 1.0
# 672 1.0
# 673 0.0 f
# 674 1.0
# 675 0.0 ffff
# 676 1.0
# 677 0.0 Trace
# 678 0.0 Trace
# 679 0.5 ffff,ea
# 680 1.0
# 681 0.0 kernel
# 682 0.0 e
# 683 1.0
# 684 0.0 Trace
# 685 1.0
# 686 1.0
# 687 0.3 ffffffffc,bd,c,pcnet,start,xmit,b
# 688 0.333333333333 b,irq,exit,xa
# 689 1.0
# 690 0.333333333333 ffffffff,acdd,scheduler,ipi
# 691 0.428571428571 ffffffff,bf,smp,reschedule
# 692 0.444444444444 d,dev,hard,start,xmit
# 693 0.666666666667 b,reschedule
# 694 0.375 c,sch,direct,xmit,xfc
# 695 1.0
# 696 0.375 ffffffff,dded,dev,queue,xmit
# 697 0.375 f,raw,spin,unlock,irqrestore
# 698 1.0
# 699 0.375 c,ata,scsi,queuecmd,xb
# 700 1.0
# 701 0.428571428571 e,dev,queue,xmit
# 702 0.428571428571 eb,ip,finish,output
# 703 1.0
# 704 0.5 f,alloc,request,struct
# 705 0.555555555556 e,ip,finish,output
# 706 1.0
# 707 0.125 ffffffff,cd,blk,execute,rq,nowait,xb
# 708 0.428571428571 c,nf,hook,slow
# 709 0.444444444444 ffffffff,cd,blk,execute,rq
# 710 0.333333333333 ffffffff,ip,mc,output
# 711 0.285714285714 ffffffff,fb,ip,local,out
# 712 0.285714285714 ffffffff,bdb,bio,phys,segments
# 713 0.5 b,ip,flush,pending,frames
# 714 0.555555555556 blk,rq,bio,prep
# 715 0.285714285714 ffffffff,fba,ip,local,out
# 716 0.25 ffffffff,ccff,blk,rq,map,kern
# 717 0.285714285714 ffffffff,da,ip,send,skb
# 718 0.375 ffffffff,bb,f,scsi,execute
# 719 0.333333333333 ffffffff,udp,send,skb
# 720 1.0
# 721 0.2 ffffffff,bd,ae,scsi,execute,req,flags,e
# 722 1.0
# 723 0.25 ffffffff,cebf,sr,check,events,xb
# 724 0.2 ffffffff,udp,sendmsg,x,xae
# 725 0.428571428571 c,cdrom,check,events
# 726 0.25 ffffffff,ded,aa,sock,msg,perm
# 727 0.4 ffffffff,a,sr,block,check,events
# 728 0.571428571429 f,inet,sendmsg
# 729 0.428571428571 d,disk,check,events
# 730 0.333333333333 ffffffff,eae,sock,sendmsg
# 731 0.571428571429 d,disk,events
# 732 0.571428571429 d,SYSC,sendto
# 733 1.0
# 734 0.375 f,poll,select,copy,remaining
# 735 1.0
# 736 0.333333333333 ffffffff,fbee,SyS,sendto
# 737 0.428571428571 f,entry,SYSCALL,fastpath
# 738 1.0
# 739 1.0
# 740 1.0
# 741 1.0
# 742 1.0
# 743 1.0
# 744 0.0 x
# 745 1.0
# 746 0.0 e
# 747 1.0
# 748 1.0
# 749 0.0 e
# 750 0.0 kernel
# 751 1.0
# 752 1.0
# 753 1.0
# 754 1.0
# 755 1.0
# 756 0.375 ffffffff,def,submit,bh,wbc
# 757 0.0 x
# 758 0.5 e,submit,bh
# 759 0.5 ext,read,inode,bitmap
# 760 1.0
# 761 0.555555555556 ffffffff,cab,ext,new
# 762 1.0
# 763 0.571428571429 a,ext,mkdir
# 764 0.333333333333 a,vfs,mkdir,xb
# 765 1.0
# 766 0.5 kernel
# 767 0.571428571429 a,SyS,mkdir
# 768 1.0
# 769 0.0 a
# 770 0.428571428571 f,entry,SYSCALL,fastpath
# 771 0.0 x
# 772 1.0
# 773 0.0 kernel
# 774 1.0
# 775 1.0
# 776 0.0 b
# 777 0.0 b
# 778 0.0 b
# 779 1.0
# 780 0.0 c
# 781 1.0
# 782 0.0 f
# 783 1.0
# 784 0.0 c
# 785 0.0 c
# 786 1.0
# 787 0.0 b
# 788 0.0 b
# 789 0.0 b
# 790 0.0 b
# 791 0.0 b
# 792 1.0
# 793 1.0
# 794 0.0 b
# 795 0.0 b
# 796 0.0 b
# 797 1.0
# 798 0.0 b
# 799 0.0 b
# 800 0.0 b
# 801 0.0 b
# 802 0.0 b
# 803 1.0
# 804 1.0
# 805 0.0 cb
# 806 1.0
# 807 0.0 c
# 808 1.0
# 809 0.0 e
# 810 1.0
# 811 1.0
# 812 0.5 kernel
# 813 1.0
# 814 0.0 kernel
# 815 0.0 e
# 816 0.0 e
# 817 0.0 e
# 818 0.0 e
# 819 0.0 e
# 820 0.0 e
# 821 1.0
# 822 0.0 c
# 823 0.0 c
# 824 0.0 kernel
# 825 0.0 fb
# 826 0.0 fb
# 827 0.0 fb
# 828 0.0 fb
# 829 0.0 fb
# 830 0.0 fb
# 831 0.0 fb
# 832 0.0 fb
# 833 0.0 fb
# 834 1.0
# 835 1.0
# 836 1.0
# 837 0.75 kernel
# 838 0.0 ff
# 839 1.0
# 840 0.0 c
# 841 1.0
# 842 0.0 kernel
# 843 0.0 e
# 844 0.0 e
# 845 1.0
# 846 1.0
# 847 0.0 f
# 848 0.0 kernel
# 849 0.0 bc
# 850 0.0 bc
# 851 1.0
# 852 1.0
# 853 1.0
# 854 0.0 f
# 855 1.0
# 856 1.0
# 857 0.0 c
# 858 0.0 c
# 859 0.0 c
# 860 0.0 c
# 861 0.0 c
# 862 0.0 c
# 863 0.0 c
# 864 1.0
# 865 1.0
# 866 1.0
# 867 0.5 kernel
# 868 1.0
# 869 0.0 c
# 870 1.0
# 871 0.0 kernel,mptscsih,ioc,attempting,task,abort,sc,ffff
# 872 0.0 kernel,sd,sda,tag,CDB,Read
# 873 0.0 kernel,mptscsih,ioc,task,abort,SUCCESS,rv,sc,ffff
# 874 0.714285714286 systemd,journald
# 875 1.0
# 876 1.0
# 877 1.0
# 878 1.0
# 879 1.0
# 880 0.166666666667 Starting,Flush,Journal,to,Persistent,Storage
# 881 0.166666666667 Started,Flush,Journal,to,Persistent,Storage
# 882 0.2 Started,udev,Kernel,Device
# 883 0.3 CMD,command,v,debian,sa,null,debian,sa
# 884 1.0
# 885 1.0
# 886 1.0
# 887 1.0
# 888 1.0
# 889 1.0
# 890 1.0
# 891 1.0
# 892 1.0
# 893 1.0
# 894 1.0
# 895 1.0
# 896 1.0
# 897 1.0
# 898 1.0
# 899 1.0
# 900 1.0
# 901 1.0
# 902 1.0
# 903 1.0
# 904 0.3 CMD,command,v,debian,sa,null,debian,sa
# 905 1.0
# 906 1.0
# 907 1.0
# 908 1.0
# 909 1.0
# 910 1.0
# 911 1.0
# 912 1.0
# 913 1.0
# 914 0.3 CMD,command,v,debian,sa,null,debian,sa
# 915 1.0
# 916 1.0
# 917 1.0
# 918 1.0
# 919 1.0
# 920 1.0
# 921 1.0
# 922 1.0
# 923 1.0
# 924 1.0
# 925 1.0
# 926 1.0
# 927 1.0
# 928 1.0
# 929 1.0
# 930 1.0
# 931 1.0
# 932 1.0
# 933 1.0
# 934 1.0
# 935 1.0
# 936 1.0
# 937 1.0
# 938 0.3 CMD,command,v,debian,sa,null,debian,sa
# 939 1.0
# 940 1.0
# 941 1.0
# 942 1.0
# 943 1.0
# 944 1.0
# 945 1.0
# 946 1.0
# 947 1.0
# 948 1.0
# 949 1.0
# 950 1.0
# 951 1.0
# 952 1.0
# 953 1.0
# 954 1.0
# 955 1.0
# 956 1.0
# 957 1.0
# 958 1.0
# 959 1.0
# 960 1.0
# 961 1.0
# 962 1.0
# 963 1.0
# 964 1.0
# 965 1.0
# 966 1.0
# 967 1.0
# 968 0.3 CMD,command,v,debian,sa,null,debian,sa
# 969 1.0
# 970 0.3 CMD,command,v,debian,sa,null,debian,sa
# 971 1.0
# 972 1.0
# 1323 1.0
# 1324 1.0
# 1325 1.0
# 1326 0.7 refresh,exited,status,FAILURE
# 1327 0.03125 snap,error,cannot,list,updates,cannot,list,snaps,cannot,list,updates,Post,https,search,apps,com,api,v,metadata,fields,anon,download,url,Carchitecture,Cchannel,Cdownload,sha,Csummary,Cdescription,Cbinary,filesize,Cdownload,url,Cicon,url,Clast,updated,Cpackage,name,Cprices,Cpublisher,Cratings,average,Crevision,Csnap,id,Csupport,url,Ctitle,Ccontent,Cversion,Corigin,Cprivate,Cconfinement,dial,tcp,lookup,search,apps,com,on,server,misbehaving
# 1328 0.928571428571 refresh
# 1329 0.571428571429 systemd,to,start
# 1330 1.0
# 1331 0.857142857143 refresh
# 1332 1.0
# 1333 0.625 refresh,result,exit
# 1334 1.0
# 1335 1.0
# 1336 1.0
# 1337 1.0
# 1338 1.0
# 1339 1.0
# 1340 1.0
# 1341 1.0
# 1342 1.0
# 1343 1.0
# 1344 1.0
# 1345 1.0
# 1346 0.777777777778 xid,xd
# 1347 1.0
# 1348 1.0
# 1349 1.0
# 1350 1.0
# 1351 1.0
# 1352 1.0
# 1353 1.0
# 1354 1.0
# 1355 1.0
# 1356 1.0
# 1357 1.0
# 1358 1.0
# 1359 1.0
# 1360 1.0
# 1361 1.0
# 1362 1.0
# 1363 1.0
# 1364 1.0
# 1365 1.0
# 1366 1.0
# 1367 1.0
# 1368 1.0
# 1369 1.0
# 1370 1.0
# 1371 1.0
# 1372 1.0
# 1373 1.0
# 1374 1.0
# 1375 1.0
# 1376 1.0
# 1377 1.0
# 1378 1.0
# 1379 1.0
# 1380 1.0
# 1381 1.0
# 1382 1.0
# 1383 1.0
# 1384 1.0
# 1385 1.0
# 1386 1.0
# 1387 0.25 autoipd,ens,Found,user,autoipd,UID,and,group,autoipd,GID
# 1388 0.2 autoipd,ens,Successfully,called,chroot
# 1389 0.166666666667 autoipd,ens,Successfully,dropped,root,privileges
# 1390 0.4 autoipd,ens,Starting
# 1391 1.0
# 1392 1.0
# 1393 0.375 autoipd,ens,Callout,BIND,address
# 1394 1.0
# 1395 1.0
# 1396 1.0
# 1397 1.0
# 1398 1.0
# 1399 1.0
# 1400 1.0
# 1401 0.333333333333 autoipd,ens,Successfully,claimed
# 1402 0.2 autoipd,ens,Got,SIGTERM,quitting
# 1403 0.375 autoipd,ens,Callout,STOP,address
# 1404 1.0
# 1405 1.0
# 1406 1.0
# 1407 1.0
# 1408 1.0
# 1409 1.0
# 1410 1.0
# 1411 1.0
# 1412 1.0
# 1413 1.0
# 1414 1.0
# 1415 1.0
# 1416 1.0
# 1417 1.0
# 1418 1.0
# 1419 1.0
# 1420 1.0
# 1421 1.0
# 1422 0.3 CMD,command,v,debian,sa,null,debian,sa
# 1423 1.0
# 1424 1.0
# 1425 1.0
# 1426 1.0
# 1427 1.0
# 1428 1.0
# 1429 1.0
# 1430 1.0
# 1431 1.0
# 1432 1.0
# 1433 1.0
# 1434 1.0
# 1435 1.0
# 1436 1.0
# 1437 1.0
# 1438 1.0
# 1439 1.0
# 1440 1.0
# 1441 1.0
# 1442 1.0
# 1443 1.0
# 1444 1.0
# 1445 1.0
# 1446 0.3 CMD,command,v,debian,sa,null,debian,sa
# 
# 461 0.0 kernel,btrfs,xor,raid,pq,ufs,qnx
# 462 0.0 kernel,ufs,ufs,qnx
# 463 0.0 kernel,qnx,hfsplus
# 464 0.0 kernel,hfsplus,hfs
# 465 0.0 kernel,hfs,minix
# 466 0.0 kernel,minix
# 467 0.0 kernel,ntfs,msdos
# 468 0.0 kernel,ntfs,hfsplus,hfs
# 469 0.0 kernel,jfs
# 470 0.0 kernel,minix
# 471 0.0 kernel,msdos
# 472 0.0 kernel,ntfs
# 473 0.0 kernel,jfs,xfs
# 474 0.0 kernel,msdos,jfs,xfs
# 475 0.0 kernel,xfs,libcrc
# 476 0.2 kernel,libcrc,c,libcrc
# 487 0.0 kernel,vhost,vhost
# 488 0.0 kernel,macvtap
# 489 0.0 kernel
# 490 0.0 kernel
# 491 0.0 kernel
# 492 0.0 kernel
# 526 0.0 kernel,coretemp
# 534 0.0 kernel,snd
# 535 0.0 kernel,kvm
# 536 0.0 kernel
# 537 0.0 kernel
# 541 0.0 kernel,irqbypass
# 545 0.0 kernel,nfit
# 553 0.0 kernel
# 559 0.0 kernel
# 560 0.0 kernel
# 564 0.0 kernel
# 565 0.0 kernel
# 566 0.0 kernel
# 567 0.0 kernel
# 568 0.0 kernel
# 569 0.0 kernel
# 570 0.0 kernel
# 571 0.0 kernel
# 573 0.0 kernel
# 574 0.0 kernel
# 578 0.0 kernel
# 579 0.0 kernel
# 580 0.0 kernel
# 581 0.0 kernel
# 582 0.0 kernel
# 591 0.0 kernel
# 592 0.0 kernel
# 593 0.0 kernel
# 594 0.0 kernel
# 599 0.0 kernel
# 600 0.0 kernel
# 601 0.0 fjes
# 602 0.0 fjes
# 612 0.14 Workqueue,events,freezable,power,disk,events
# 614 0.0 ffff
# 635 0.17 RAX,ffff,fbc,RBX,dc
# 649 0.0 kernel,ab
# 653 0.0 kernel
# 657 0.0 b
# 658 0.0 b
# 660 0.0 d
# 661 0.0 d
# 662 0.0 kernel
# 666 0.0 ab
# 673 0.0 f
# 675 0.0 ffff
# 677 0.0 Trace
# 678 0.0 Trace
# 681 0.0 kernel
# 682 0.0 e
# 684 0.0 Trace
# 707 0.13 ffffffff,cd,blk,execute,rq,nowait,xb
# 721 0.2 ffffffff,bd,ae,scsi,execute,req,flags,e
# 724 0.2 ffffffff,udp,sendmsg,x,xae
# 744 0.0 x
# 746 0.0 e
# 749 0.0 e
# 750 0.0 kernel
# 757 0.0 x
# 769 0.0 a
# 771 0.0 x
# 773 0.0 kernel
# 776 0.0 b
# 777 0.0 b
# 778 0.0 b
# 780 0.0 c
# 782 0.0 f
# 784 0.0 c
# 785 0.0 c
# 787 0.0 b
# 788 0.0 b
# 789 0.0 b
# 790 0.0 b
# 791 0.0 b
# 794 0.0 b
# 795 0.0 b
# 796 0.0 b
# 798 0.0 b
# 799 0.0 b
# 800 0.0 b
# 801 0.0 b
# 802 0.0 b
# 805 0.0 cb
# 807 0.0 c
# 809 0.0 e
# 814 0.0 kernel
# 815 0.0 e
# 816 0.0 e
# 817 0.0 e
# 818 0.0 e
# 819 0.0 e
# 820 0.0 e
# 822 0.0 c
# 823 0.0 c
# 824 0.0 kernel
# 825 0.0 fb
# 826 0.0 fb
# 827 0.0 fb
# 828 0.0 fb
# 829 0.0 fb
# 830 0.0 fb
# 831 0.0 fb
# 832 0.0 fb
# 833 0.0 fb
# 838 0.0 ff
# 840 0.0 c
# 842 0.0 kernel
# 843 0.0 e
# 844 0.0 e
# 847 0.0 f
# 848 0.0 kernel
# 849 0.0 bc
# 850 0.0 bc
# 854 0.0 f
# 857 0.0 c
# 858 0.0 c
# 859 0.0 c
# 860 0.0 c
# 861 0.0 c
# 862 0.0 c
# 863 0.0 c
# 869 0.0 c
# 871 0.0 kernel,mptscsih,ioc,attempting,task,abort,sc,ffff
# 872 0.0 kernel,sd,sda,tag,CDB,Read
# 873 0.0 kernel,mptscsih,ioc,task,abort,SUCCESS,rv,sc,ffff
# 880 0.17 Starting,Flush,Journal,to,Persistent,Storage
# 881 0.17 Started,Flush,Journal,to,Persistent,Storage
# 882 0.2 Started,udev,Kernel,Device
# 1306 0.13 dhclient,receive,packet,failed,ens,Network,is
# 1327 0.03 snap,error,cannot,list,updates,cannot,list,snaps,cannot,list,updates,Post,https,search,apps,com,api,v,metadata,fields,anon,download,url,Carchitecture,Cchannel,Cdownload,sha,Csummary,Cdescription,Cbinary,filesize,Cdownload,url,Cicon,url,Clast,updated,Cpackage,name,Cprices,Cpublisher,Cratings,average,Crevision,Csnap,id,Csupport,url,Ctitle,Ccontent,Cversion,Corigin,Cprivate,Cconfinement,dial,tcp,lookup,search,apps,com,on,server,misbehaving
# 1388 0.2 autoipd,ens,Successfully,called,chroot
# 1389 0.17 autoipd,ens,Successfully,dropped,root,privileges
# 1402 0.2 autoipd,ens,Got,SIGTERM,quitting

# %%
sf_error = gl.SFrame({'no.': list_number_q, 'score': list_score_q, 'error_text': list_content_q})
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to sayyes566@gmail.com and will expire on March 01, 2018.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1490084597.log

# %%
sf_error.head
# Out:
# <bound method SFrame.head of Columns:
# 	error_text	str
# 	no.	int
# 	score	float
#
# Rows: 159
#
# Data:
# +-------------------------------+-----+-------+
# |           error_text          | no. | score |
# +-------------------------------+-----+-------+
# |        kernel,btrfs,xor       | 456 |  0.0  |
# |           kernel,xor          | 457 |  0.0  |
# |         kernel,raid,pq        | 459 |  0.0  |
# |         kernel,raid,pq        | 460 |  0.0  |
# | kernel,btrfs,xor,raid,pq,u... | 461 |  0.0  |
# |       kernel,ufs,ufs,qnx      | 462 |  0.0  |
# |       kernel,qnx,hfsplus      | 463 |  0.0  |
# |       kernel,hfsplus,hfs      | 464 |  0.0  |
# |        kernel,hfs,minix       | 465 |  0.0  |
# |          kernel,minix         | 466 |  0.0  |
# +-------------------------------+-----+-------+
# [159 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.>

# %%
sf_error.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:35781/index.html
# Opening Canvas in default web browser.

# %%
gl.canvas.set_target('ipynb')

# %%
sf_error['error_text'].show(view="Categorical")

# %%
sf_error['score'].show(view="Categorical")

# %%
sf_error.show(view = "Bar Chart", x="error_text", y = "score")

# %%
sf_error.show(view = "Scatter Plot", x="no.", y = "score")
